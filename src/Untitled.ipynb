// %%
const a = 1+2

// %%
console.log(a)
// Out:
// 3

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";

import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";

import { StateGraph } from "@langchain/langgraph";
import * as d3 from "d3";
import * as tslab from "tslab";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import {
  ChatPromptTemplate,
  MessagesPlaceholder,
} from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";
// Out:
// node:internal/modules/cjs/loader:1681
//       throw err;
//       ^
//
// Error [ERR_REQUIRE_ESM]: require() of ES Module C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\d3\src\index.js from C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js not supported.
// Instead change the require of index.js in C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js to a dynamic import() which is available in all CommonJS modules.
//     at TracingChannel.traceSync (node:diagnostics_channel:315:14)
//     at Object.apply (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\executor.js:61:24)
//     at evalmachine.<anonymous>:44:25
//     at evalmachine.<anonymous>:65:3 {
//   code: 'ERR_REQUIRE_ESM'
// }

// %%
import * as tslab from "tslab";

// %%
tslab.display.png(canvas.toBuffer());
// Out:
// 1:19 - Cannot find name 'canvas'.

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";
import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";
import { StateGraph } from "@langchain/langgraph";
import * as d3 from "d3";
import * as tslab from "tslab";
import fs from "fs";
import path from "path";
import os from "os";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import { ChatPromptTemplate, MessagesPlaceholder } from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";
// Out:
// node:internal/modules/cjs/loader:1681
//       throw err;
//       ^
//
// Error [ERR_REQUIRE_ESM]: require() of ES Module C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\d3\src\index.js from C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js not supported.
// Instead change the require of index.js in C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js to a dynamic import() which is available in all CommonJS modules.
//     at TracingChannel.traceSync (node:diagnostics_channel:315:14)
//     at Object.apply (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\executor.js:61:24)
//     at evalmachine.<anonymous>:44:25
//     at evalmachine.<anonymous>:71:3 {
//   code: 'ERR_REQUIRE_ESM'
// }

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";

import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";

import { StateGraph } from "@langchain/langgraph";
const d3 = await import("d3");
import * as tslab from "tslab";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import {
  ChatPromptTemplate,
  MessagesPlaceholder,
} from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";
// Out:
// 19:20 - 'RunnableConfig' is a type and cannot be imported in JavaScript files. Use 'import("@langchain/core/runnables").RunnableConfig' in a JSDoc type annotation.
// 23:174 - Types cannot appear in export declarations in JavaScript files.

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";

import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";

import { StateGraph } from "@langchain/langgraph";

import * as tslab from "tslab";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import {
  ChatPromptTemplate,
  MessagesPlaceholder,
} from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";

Error [ERR_REQUIRE_ESM]: require() of ES Module C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\d3\src\index.js from C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js not supported.
Instead change the require of index.js in C:/Coding/Projects/aiagentsexample/chatgpt-langchainjs-example/src/src.js to a dynamic import() which is available in all CommonJS modules.
    at TracingChannel.traceSync (node:diagnostics_channel:315:14)
    at Object.apply (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\executor.js:61:24)
    at evalmachine.<anonymous>:44:60
    at async evalmachine.<anonymous>:44:12 {
  code: 'ERR_REQUIRE_ESM'
}
// Out:
// 24:8 - Cannot find name 'ERR_REQUIRE_ESM'.
// 24:24 - ';' expected.
// 24:26 - Expected 1 arguments, but got 0.
// 24:36 - ';' expected.
// 24:36 - Cannot find name 'of'.
// 24:39 - Unexpected keyword or identifier.
// 24:39 - Cannot find name 'ES'.
// 24:42 - Unknown keyword or identifier. Did you mean 'module'?
// 24:42 - Cannot find name 'Module'. Did you mean 'module'?
// 24:51 - Invalid character.
// 24:52 - Cannot find name 'Coding'.
// 24:58 - Invalid character.
// 24:59 - Cannot find name 'Projects'.
// 24:67 - Invalid character.
// 24:68 - Cannot find name 'aiagentsexample'.
// 24:83 - Invalid character.
// 24:84 - Cannot find name 'chatgpt'.
// 24:92 - Cannot find name 'langchainjs'.
// 24:104 - Cannot find name 'example'.
// 24:111 - Invalid character.
// 24:112 - Cannot find name 'node_modules'.
// 24:124 - Invalid character.
// 24:125 - 'd3' refers to a UMD global, but the current file is a module. Consider adding an import instead.
// 24:127 - Invalid character.
// ...

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";

import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";

import { StateGraph } from "@langchain/langgraph";

import * as tslab from "tslab";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import {
  ChatPromptTemplate,
  MessagesPlaceholder,
} from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";
// Out:
// unexpected error: Error: Unexpected pending rebuildTimer
//     at sys.setTimeout (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:111:19)
//     at scheduleProgramUpdate (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122735:35)
//     at onSourceFileChange (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122876:7)
//     at C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122868:56
//     at updateContent (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:601:9)
//     at Object.convert (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:252:9)
// ...

// %%
const d3 = await import("d3");
console.log("D3 loaded successfully:", d3.version);
// Out:
// unexpected error: Error: Unexpected pending rebuildTimer
//     at sys.setTimeout (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:111:19)
//     at scheduleProgramUpdate (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122735:35)
//     at onSourceFileChange (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122876:7)
//     at C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122868:56
//     at updateContent (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:601:9)
//     at Object.convert (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:252:9)
// ...

// %%
console.log("asdas")
// Out:
// unexpected error: Error: Unexpected pending rebuildTimer
//     at sys.setTimeout (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:111:19)
//     at scheduleProgramUpdate (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122735:35)
//     at onSourceFileChange (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122876:7)
//     at C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\@tslab\typescript-for-tslab\lib\typescript.js:122868:56
//     at updateContent (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:601:9)
//     at Object.convert (C:\Coding\Projects\aiagentsexample\chatgpt-langchainjs-example\node_modules\tslab\dist\converter.js:252:9)
// ...

// %%
console.log(":Asdas");
// Out:
// :Asdas

// %%
import dotenv from "dotenv";
dotenv.config();

import { ToolNode } from "@langchain/langgraph/prebuilt";
import { tavily } from "@tavily/core";

import { Annotation, END, START } from "@langchain/langgraph";
import { z } from "zod";

import { StateGraph } from "@langchain/langgraph";

import * as tslab from "tslab";

import { AIMessage, BaseMessage, HumanMessage } from "@langchain/core/messages";
import {
  ChatPromptTemplate,
  MessagesPlaceholder,
} from "@langchain/core/prompts";
import { Runnable, RunnableConfig } from "@langchain/core/runnables";
import { StructuredTool, tool } from "@langchain/core/tools";
import { ChatGoogleGenerativeAI } from "@langchain/google-genai";
import { createCanvas } from "canvas";

// %%
console.log(asdas);
// Out:
// 1:13 - Cannot find name 'asdas'.
